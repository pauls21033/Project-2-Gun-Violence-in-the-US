# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
mass_all = "../Resources/mass_shootings_all.csv"
all_df = pd.read_csv(mass_all)
all_df
# Out:
#          Incident Date         State City Or County  \
# 0    November 26, 2016      Illinois        Chicago
# 1    November 25, 2016     Louisiana    New Orleans
# 2    November 24, 2016      Kentucky     Louisville
# 3    November 24, 2016      New York         Albany
# 4    November 23, 2016   Mississippi   Olive Branch
# ..                 ...           ...            ...
# 495      July 25, 2015      Virginia       Hopewell
# 496      July 24, 2015  Pennsylvania           Erie
# 497      July 23, 2015     Louisiana      Lafayette
# 498      July 22, 2015       Georgia        Suwanee
# 499      July 21, 2015       Florida  Miami Gardens
#
#                                            Address  # Killed  # Injured  \
# 0              8800 block of South Exchange Avenue         1          5
# 1                     Magnolia and Felicity Street         0          4
# 2                                  4501 W Broadway         2          5
# ...

# %%
# Create a filtered dataframe from specific columns
all_cols = ["State"]
all_transformed= all_df[all_cols].copy()

# Rename the column headers
#all_transformed = all_transformed.rename(columns={"State": "State", "# Killed": "premise_name")
                                                          

# Clean the data by dropping duplicates and setting the index
#all_transformed.drop_duplicates("id", inplace=True)
#all_transformed.set_index("id", inplace=True)

all_transformed
# Out:
#             State
# 0        Illinois
# 1       Louisiana
# 2        Kentucky
# 3        New York
# 4     Mississippi
# ..            ...
# 495      Virginia
# 496  Pennsylvania
# 497     Louisiana
# 498       Georgia
# 499       Florida
#
# [500 rows x 1 columns]

# %%
all_transformed.count()
# Out:
# State    500
# dtype: int64

# %%
mass_occurances = all_transformed.groupby(['State']).size()

# %%
display(mass_occurances)
# Out:
# State
# Alabama                 15
# Arizona                  6
# Arkansas                 4
# California              52
# Colorado                 8
# Connecticut              5
# Delaware                 2
# District of Columbia     6
# Florida                 42
# Georgia                 23
# Illinois                54
# Indiana                 13
# Iowa                     1
# Kansas                   5
# Kentucky                 2
# Louisiana               22
# Maryland                14
# Massachusetts            3
# Michigan                14
# Minnesota               10
# Mississippi              7
# Missouri                14
# Nebraska                 1
# Nevada                   4
# New Jersey               9
# New Mexico               4
# New York                19
# North Carolina          12
# Ohio                    15
# Oklahoma                 2
# Oregon                   3
# Pennsylvania            19
# South Carolina          12
# South Dakota             1
# ...

# %%
# Export a Pandas Dataframe to CSV
# Relative File Path
mass_occurances.to_csv('mass_cleaned.csv')

# %%
protocol = 'postgresql'
username = 'postgres'
password = 'password'
host = 'localhost'
port = 5432
database_name = 'mass_db'
rds_connection_string = f'{protocol}://{username}:{password}@{host}:{port}/{database_name}'
engine = create_engine(rds_connection_string)

connection_string = "postgres:postgres@localhost:5432/mass_db"
engine = create_engine(f'postgresql://{connection_string}')

# %%
#engine.table_names()
